# %% [markdown]
# # Generación de Texto con LSTM
# En este Notebook se llevará a cabo el ejemplo práctico de generación de textos basados en escritos de Nietzsche del capítulo 8 del libro "Deep Learning con Python", de François Chollet, titulado "Deep Learning generativo".
#
# ## Implementación de generación de texto a nivel de carácter
# Para este ejemplo haremos uso de uno de los textos que están incluidos en keras, en su módulo *utils*. En concreto, será un texto de Nietzsche en inglés. La clave para la generación de textos es tener un texto o conjunto de ellos lo suficientemente grande como para que se pueda llegar a aprender algún modelo de estilo de redacción.

# %%
import keras
import numpy as np

path = keras.utils.get_file('nietzsche.txt', origin='https://s3.amazonaws.com/text-datasets/nietzsche.txt')
text = open(path).read().lower()
print('Longitud del corpus:', len(text))
# Out:
# Downloading data from https://s3.amazonaws.com/text-datasets/nietzsche.txt
# 606208/600901 [==============================] - 1s 1us/step
# Longitud del corpus: 600901

# %% [markdown]
# Ahora extraeremos secuencias que se solapen parcialmente. Estas secuencias tendrán longitud *maxlen* y serán tomadas cada *step* caracteres respecto al inicio de la anterior. Tras tomar las secuencias, les aplicaremos codificación one-hot y las colocaremos en una matriz 3D *x* con forma (*sequences*, *maxlen*, *unique_characters*). También prepararemos una matriz *y* que contenga los objetivos correspondientes.

# %%
maxlen = 60
step = 3
sentences = []
next_chars = []

for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i: i + maxlen])
    next_chars.append(text[i + maxlen])
print('Número de secuencias:', len(sentences))

#Se comprueban los caracteres únicos del texto.
chars = sorted(list(set(text)))
print('Caracteres únicos:', len(chars))
#Creamos un diccionario que mapee los caracteres únicos con su índice en 'chars'
char_indices = dict((char, chars.index(char)) for char in chars)

#Ahora realizamos codificación one-hot de los caracteres
print('Vectorización...')

x = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
y = np.zeros((len(sentences), len(chars)), dtype=np.bool)

for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        x[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1
    
print('\nEjemplo de muestra en X:\n')
print(x[0])
print('\nEjemplo de objetivo en Y:\n')
print(y[0])
# Out:
# Número de secuencias: 200281
# Caracteres únicos: 59
# Vectorización...
#
# Ejemplo de muestra en X:
#
# [[False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]
#  ...
#  [False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]]
#
# Ejemplo de objetivo en Y:
#
# [False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False  True False False False
#  False False False False False False False False False False False]

# %% [markdown]
# ## Creación de la red
# La red que vamos a utilizar es sencilla, utilizará una capa *LSTM* seguida de un clasificador *Dense* con función *softmax* para todos los caracteres posibles.

# %%
from keras import layers

model = keras.models.Sequential()
model.add(layers.LSTM(128, input_shape=(maxlen, len(chars))))
model.add(layers.Dense(len(chars), activation='softmax'))

# %% [markdown]
# Dado que los caracteres están codificados haciendo uso de one-hot, podemos utilizar *categorical_crossentropy* como función de pérdida.

# %%
optimizer = keras.optimizers.RMSprop(lr=0.01)
model.compile(loss='categorical_crossentropy', optimizer=optimizer)

# %% [markdown]
# ## Entrenamiento del modelo y muestreo
# Dado un modelo entrenado y un fragmento de texto como semilla, podemos generar nuevo texto haciendo esto repetidas veces:
#
# 1. Extraer del modelo la distribución de probabilidad del siguiente caracter, teniendo en cuenta el texto generado hasta ahora.
# 2. Cambiar los pesos de la distribución en función de la temperatura determinada.
# 3. Muestrear el siguiente caracter al azar según la distribución con los pesos modificados.
# 4. Añadir el caracter al final del texto disponible
#
# A continuación definiremos la función de muestreo de caracteres.

# %%
def sample(preds, temperature=1.0):
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

# %% [markdown]
# Ahora vamos a entrenar el modelo. El siguiente bucle entrena y genera texto en cada época. En cada una de ellas generará texto con distintas temperaturas, de esta manera podremos comprobar la evolución del modelo y cómo afecta la temperatura en la generación de texto.
#
# **Aviso**: Las 60 épocas configuradas por defecto pueden tardar bastante tiempo en completarse

# %%
import random
import sys

for epoch in range(1, 60):
    print('Época ', epoch)
    # Entrena al modelo para 1 época con los datos de entrenamiento
    model.fit(x, y,
              batch_size=128,
              epochs=1)

    # Selecciona una semilla de texto aleatoriamente
    start_index = random.randint(0, len(text) - maxlen - 1)
    generated_text = text[start_index: start_index + maxlen]
    print('--- Generando con la semill: "' + generated_text + '"')
    
    #Para cada época, genera texto con temperatura 0.2, 0.5, 1.0 y 1.2
    for temperature in [0.2, 0.5, 1.0, 1.2]:
        print('------ Temperatura:', temperature)
        sys.stdout.write(generated_text)

        # Generamos 400 caracteres cada vez
        for i in range(400):
            sampled = np.zeros((1, maxlen, len(chars)))
            for t, char in enumerate(generated_text):
                sampled[0, t, char_indices[char]] = 1.

            preds = model.predict(sampled, verbose=0)[0]
            next_index = sample(preds, temperature)
            next_char = chars[next_index]

            generated_text += next_char
            generated_text = generated_text[1:]

            sys.stdout.write(next_char)
            sys.stdout.flush()
        print()
# Out:
# Época  1
# 1565/1565 [==============================] - 91s 58ms/step - loss: 1.9768
# --- Generando con la semill: "l of women, in the marriage customs, in the
# relations of old"
# ------ Temperatura: 0.2
# l of women, in the marriage customs, in the
# relations of old and the something the self-he still the considerate of the will the self-profers and with the considerate of the consideration of the interpical and still the considerate of the considerate of the considerate of the considerate of the will the self-chand of the self the self-profers of the self-profers of the self-profering in the self-profertion of the considerate of the self-man and the stringt
# ------ Temperatura: 0.5
# rofertion of the considerate of the self-man and the stringtion of the fires to in its a profer it self-men and the worlds he self har a that is the sufferent that the entitions that the desprofering and the standination of the man a thing and strongs and the man the herself believe and though of that our the interpian and them from the some the conseds the conscience the conseas the chaistions
# and in this he such is the dears in the contrance of the press
# ------ Temperatura: 1.0
# d in this he such is the dears in the contrance of the pressing in the ansshange of the conspitice as huwad. he man probtion of
# a then unself-men then whon onom besaritys in whine lely interpiness it as brock who
# he eashers me
# pinistly: huther howe rateral wife impustion is firghing in elsone they present is eligan; of there
# howrubed, as the same a tho instinct, heres so
# deas dopeningo beations of thener
# to
# a
# presely in pation and natate dangerics of who
# ------ Temperatura: 1.2
# f thener
# to
# a
# presely in pation and natate dangerics of who sfob ; song
# besire, becom and
# was his maniffentkingr centermansery and deld, a callod fteei, cise him. headionnes wo ngtents, .
#
# ": somlakl
# mis,ror, curtude, fro"suf
# theseliagiently
# is
# unafoment, but"s there
# forming they untan is adiery, they dorphe, if a preguring there, of
# free re. he cons
# ort howher, acone. the alselides have to dore ; besesse men a sho thach--assquatory atshables by thesy fr
# Época  2
# 1565/1565 [==============================] - 92s 59ms/step - loss: 1.6186
# --- Generando con la semill: " that the foundation of the emotions, called
# "life," is conv"
# ------ Temperatura: 0.2
#  that the foundation of the emotions, called
# "life," is conviniater the soulse and all the desire to anything and in the soul and all those and always and all the invalical proveration of the free spirit to a power that it is a most the soul and a success of the strong and and the sense of the whole that it is the spirit to the companical instance of the fact the success of the soulse and most be an individual in the world and the spirit of the anything an
# ------ Temperatura: 0.5
# an individual in the world and the spirit of the anything and the self-desire and alided the most another and whole as the feeling and the divertained to the mind in the segaries to a power
# even its also the sense of the good and the considerity of the and the himself and indere in the companity and
# decesse and there is a possible as a good not be politic of the world of the chartem of the consider the sunsible has conscioual and mose for himself, what
# we
# ------ Temperatura: 1.0
# r the sunsible has conscioual and mose for himself, what
# we convaring emotouts,
# intasioned, it
# is
# himsele for also well to that pat presion. throump blezeoves than i sa
# existials of modes to an awably as siscopency if he aven in this have thereure possible of aich one thorisism assetiques, hencences, the own as the live is efseption, those sudders do beyose love breagh of herdive to teinjequare-adual, who, as
# inderes been word not free detery
# deward words
# ------ Temperatura: 1.2
# ual, who, as
# inderes been word not free detery
# deward words of censy its defpemive, whom who pussione. it: with.
#
# wlithe to with
# the form our take witely, revidg of them what hione, the lough"tity.
# in
# more moceas, but othel, sole who,y, by the coms: go anowiister himeed
# and putpen, not indegecl evolobsess". ; our effect and os-truty?ly
# rightles;
# rever incon;
# in, feelings would trate: the will, to looking of the paty, withiod it to and: becaoe valulne to p
# Época  3
# 1565/1565 [==============================] - 93s 59ms/step - loss: 1.5291
# --- Generando con la semill: "ed this time under
# the new form of the scientific spirit; mo"
# ------ Temperatura: 0.2
# ed this time under
# the new form of the scientific spirit; more the standards of the standers and the stand of the stander the spiritual the state of the states of the conditions and the standers of the same the stand and the probably the standers of the significe of the present of the spiritual states of the spiritual and the states of the spiritual instance, and the stand of the sense of the standing the religious and the standers of the spiritual in the
# ------ Temperatura: 0.5
# ding the religious and the standers of the spiritual in the determine for the superts them, for one's some he has nature that is a derial friends of the class and dearistoce of the signcy of the latter the thought the disto the greem the most denicate of the personal men and have only a states of the most permans, the still and the man when it is also free spiritual probably be an its also the end as have been standers of a the work of the greek and man as
# ------ Temperatura: 1.0
#  as have been standers of a the work of the greek and man as nothing speciange of the from a whom also he facts crating and hether is different "god about in nother should be nature masif or as he  only the instante a well same the exappains, he rears aponts.
#
#
# ym thelibbrspers, the ombility say of y-he but
# them fert-attions passial as in
# ever sa past call the facturable
# conceads only
# new theor spiritual which most pethoided there end rare and they be cind
# ------ Temperatura: 1.2
# iritual which most pethoided there end rare and they be cinduatate socimanicsalctic,
# at as makem,ownol difficupti
# sod.=--iful
#
# mostal vers their whoreaty. a new, whecom this is right at thus
# falog of the mirming that as anly
# of really tour ford netible, wish, suffician gime wy
# favours, though--supragen freed knowledgoy in eherearting not! is s asty i  sil rack."
# evolute that will
# rats
# hitherto knowledgewnewlyernt "pri-poviriwation, notunaual lwort, the "f
# Época  4
# 1565/1565 [==============================] - 94s 60ms/step - loss: 1.4824
# --- Generando con la semill: "rlike, wisely silent, reserved, and reticent
# men (and as suc"
# ------ Temperatura: 0.2
# rlike, wisely silent, reserved, and reticent
# men (and as such allow to the greatest of the structure to the same thing the sense of the sense of the same thing the sense of the state of the moral the world to the sense of the sense of the sense of the subtle to the self-superion of the sense of the sense of the moral perhaps the serving and superioring the self-desire the senses of the sense of the same
# the subtle subtle sense of the struggle and intellect
# ------ Temperatura: 0.5
# e same
# the subtle subtle sense of the struggle and intellectual preventary of the light to all this sellom--are men into the good self-same smout of this result the sense, in the world the structure and power the world resist, in all philosophy and the desire, the end in the secred to great and men of the loger the sense, it respect of strives the superiors of the germans and subjects
# stepticism of the moral perhaps himself of the emotions of this sense of
# ------ Temperatura: 1.0
# f the moral perhaps himself of the emotions of this sense of the proc unter real curromable
# dose of
# remagiscerary themm made which benestain is
# et just for this
# rended, the fuggoaly, in all.
# distumsives nowader, he spiller. his specialing their evil. the matter, bell-ined.--honest at an the
# temenness whichhe meves, the prematory and
# a
# last
# thring to
# significing; who or typelilarious astic relation and are, perhaps
# foom knot of by lije theredo one! more tha
# ------ Temperatura: 1.2
#  and are, perhaps
# foom knot of by lije theredo one! more that now and tbut he very me-cusser, and art, greuth--in
# the sublatated from soulhistic in him is the picture gred, and the generally catail and chris limt--grdacyed of done moraligy.blauthous. onetial to
# again. notudefg"iful more middone, every
# greeaun, ever
# wfrees grimatist. is it not marty pajor, whatever free tignt us, shol ame o, in itself are guided him edy of leor selt medjirm, it kind of ad h
# Época  5
# 1565/1565 [==============================] - 91s 58ms/step - loss: 1.4529
# --- Generando con la semill: "es of their own personality. thus do
# many thinkers bring the"
# ------ Temperatura: 0.2
# es of their own personality. thus do
# many thinkers bring the ancious of the such a most and something which he such a more the world more sense of the most personality of the sense of the any of the strengther of the present the sense of the sense of the profoundres of the most possible in the sense of the strength of the most personality, and the best more who has been ancient of the personal comparistic the presence, the world for the world be a more and
# ------ Temperatura: 0.5
# paristic the presence, the world for the world be a more and there is the most most perhaps best into a wholly one of the self-condition of the faith; and of the contrary to which a man ready the strength--the strength in the
# deserve of is "more than be discovery in the antither in the principle to the most condition of the considerty, there is the consider the inspire
# to their desist of the conditions
# in every constabte of the extent," in the personal ast
# ------ Temperatura: 1.0
# tions
# in every constabte of the extent," in the personal astracted
# by
# the
# greums--so i gods in their experiences of elevated himself bhing
# us imperamer,
# in at which is soul, may such,r" what a free inmition; itself?
# -of his opinions with their something
# such would may manifests and
# usiveradied,w
# will be are
# sexicisism, in these nof which hi streacting misundinger ourselves
# we mo sernt in the overceners,
# and right," and now natured manyded have the opetic i
# ------ Temperatura: 1.2
# eners,
# and right," and now natured manyded have the opetic in confusiattence of our himhe become opinion,
# isfore for way
# lite
# a dandisms, mach: this indaquently
# who be oversesuably ass" its,--mingll
# ourgo., he is purped,
# much.
# ;need, in thinks from the hibde
# light forceable nods ambigiof, nothoned wagner! it is head hims"-over the ison-ionisaryshsan due aushomal, an ashowement, the
# beest noses, noth-to superage to wisodniced to
# such what se,
# by perjudici.
# Época  6
# 1565/1565 [==============================] - 88s 56ms/step - loss: 1.4318
# --- Generando con la semill: "ion (in the end,
# however, the greatness of their mission), i"
# ------ Temperatura: 0.2
# ion (in the end,
# however, the greatness of their mission), in the seem to the protection of the seem the seem that the comparison that is the seem the probably the secret and the stronger and seems the stronger of the profound the seem the seems the seem to the present and seems the seem that the seem to the sertion of the seem to the sentence of the sentement of the most moral to the stronger of the sentence, the stronger of the sentiment of the proper th
# ------ Temperatura: 0.5
# the sentence, the stronger of the sentiment of the proper that the moral metaphysical sentence of the self-contridional termousive people to one that the schocatics, and the person of the seems to the self-sour something of the opproous and the truth the deeper the compultion and although the certainly reading the self-religious and the man to one and seem may a the sentement of the feeling, and compeliages to free man as in order to metaphysic(quition of
# ------ Temperatura: 1.0
# ompeliages to free man as in order to metaphysic(quition of reprocouust "pheciedity--is more perhaps renders makes every disunceitable first as
# thought: there is
# a pirenness the signization--in haml
# extent and seeming and comes reasfations a southes
# morals, of a most and prupurse, of their moche
# not to have it doubt),--the
# philosophed," the
# resepeing
# "it, mate he very cally lead as at this
# soutrnula. only of suddedncials, men and philosophty all things fur
# ------ Temperatura: 1.2
# la. only of suddedncials, men and philosophty all things fur named theirohy which ts
# expraiting futtient
# and robrasted mimacll ethic; he have as eartly inferious
# officaire
# is
# disguises
# philosyph herman ye to anythic. he lifterers, if does up
# frithion, theirighiness: an evidennes as it
# has
# still reading eleaplay. justice.
# the rainusalm lativates ourselves. helpting
# see
# things all maanes this my
# who it is spate-young. that the states lo, he very of expireun;
# Época  7
# 1565/1565 [==============================] - 90s 58ms/step - loss: 1.4146
# --- Generando con la semill: "dence--perhaps
# among men who enjoyed even stronger and more "
# ------ Temperatura: 0.2
# dence--perhaps
# among men who enjoyed even stronger and more the senting and strength of the most distrust of the most do not the strength of the philosophers of the strong in the same time of the sense of the sense of the sentiment of the seriousness of the sentiment of the sense of the same to the consider to the sentiment of the more individual and sense of the sentiment of the sentiment and sense of the strength of the distrust of the strong sense of th
# ------ Temperatura: 0.5
# se of the strength of the distrust of the strong sense of the greek not the commenders and man and experience of one has a distinguer of the discoverers of the philosophers and the sentiment of the signification of individual and who has master of the sentiment the logic the look and the strength and inveration of the fear the condition of anything in the mirrorable minder and some to the highes more german doublerd and true, in the spirit the consciously
# ------ Temperatura: 1.0
# ore german doublerd and true, in the spirit the consciously has no long conlife is vary in such
# mackoous who the custable, spirit
# unevereens peoples.
#  booker result that knowledge, one id society,--and are ecparise, name of power! weally beeny madest with a more jurgial."
#
# 1od
# another as
# it; "wholkem coming, now laugh men has judtressness, varibied
# possible
# it man how hard to constant of minded obedience
# opines that ha trarrous first wise to our disfoved o
# ------ Temperatura: 1.2
# edience
# opines that ha trarrous first wise to our disfoved odotient and gware lattersual and sublipated the strength victo tipliss!
# -ind
# and catinn, was not upposed
# simish elsy yet possession ouff-
# houble eyes!s. in those in this fate are sorn), "be shobd docmss, behistable by people , siffectel, not to the goot ralwerwity look no long and something doet a most of them,
# i . without seriow--lstaker pspection, chois, doessoness, her good still excemsip you-c
# Época  8
# 1565/1565 [==============================] - 90s 57ms/step - loss: 1.4000
# --- Generando con la semill: "then indulge in falsehood as matter of
# course, and involunta"
# ------ Temperatura: 0.2
# then indulge in falsehood as matter of
# course, and involuntarily and seems to the superated to the spirit and altays to something some of the strength of the best in the strength of the propound the present different of the same to the soul is not to be the sense of which he something and the strength of the spirit in the soul is all the most desire to a sure many the soul is the conditions of the most soul and some of the seems of the sense of the propose
# ------ Temperatura: 0.5
#  most soul and some of the seems of the sense of the proposes it may be indiabived, and and which was only and what so in the world and altather and we desires to comes the desires, and and also in the life and stepticism to some which a negant to the same to presence of the similar the intersated and so manyer of general termon presence and the reavery as the man of the highest and former of an alloper in the struct and so i conditions of the strenge of t
# ------ Temperatura: 1.0
# lloper in the struct and so i conditions of the strenge of the midsalrestwioning to
# be"rines
# and she sibse artist too," but the became "must usgetn that altyrin
# moveance. with there arougk antidotice it to be virtuly, thought) the
# struggle through dispity of
# the armilative evil, specturary in
# the
# simwand it gives on itfle"hay what something which
# in.ten.s of intellict with
# the "tance, which onled
# some
# physiolosrical seemed, alone! rat embed and ready relig
# ------ Temperatura: 1.2
# some
# physiolosrical seemed, alone! rat embed and ready religious gre sints permitt umonul
# extest, effect discawace themselves as because oigs termire as ceoulations has notrised, at here, may make a
# viexteen"!
#
#
# fromest oncoushe
# mus, to be be the
# happiness, andsquarous fatharn moral, which he same to loved it who in the heart for inderines--estemoning all possible is malticry and goutager
# joyed it finest, bottochs, with 1 is not
# sectlestal of onouth, verft
# Época  9
# 1565/1565 [==============================] - 85s 54ms/step - loss: 1.3893
# --- Generando con la semill: " also implies
# the same as "more complete beasts").
#
# 258. cor"
# ------ Temperatura: 0.2
#  also implies
# the same as "more complete beasts").
#
# 258. corresponded the strength of the strength of the strengther of the strength of the strength of the superiority of the most problem of the strength of the superiority of the strength of the superiority and such an all the surelith and surelited the most conscience of the surelith is all the strength of the sentence of the same distrust is the surelith
# sense of the strength of the surelith of the sente
# ------ Temperatura: 0.5
#  surelith
# sense of the strength of the surelith of the sentent sapposition of the constantly, which has a thing is an and made pare is self-events of the standpount as in the surmountory of the sentence of the morality and semoliting
# in the such and still apparents and the thoughts of which the becomes allow his own doner of the dream to the strength of the still to the secting to the entire will have the most past of the morality all that it will in the s
# ------ Temperatura: 1.0
# have the most past of the morality all that it will in the supernest instards the "grodinglys
# in this blink in the macking of this conduct
# on so long
# ascame, if only childrfuse. yes devary cough, time his hostile and if noble from should that is at the soul dance, quite itself the stronger ethics is the by brought over i persignory is we lessing, you
# agory when or as--as the truded soul is that problem of life. the close becomes astic of "means to rands, w
# ------ Temperatura: 1.2
# oblem of life. the close becomes astic of "means to rands, whollica!" re?
#
#
# 102
#
# =circumstances but
# certain tegarity is thousarded own impringne to which a ourselvcy stabled so, as in their enresst,
# cameges
# et inathing haxd arlituquenest
# that was desires--the in ones of lat underousy. the wholeers, but our development them invatumesally thus we sprigure thems elfiqution
# of ill dones, the strengteries,
# as the call" it ise; however, more which be dieles our
# Época  10
# 1565/1565 [==============================] - 97s 62ms/step - loss: 1.3793
# --- Generando con la semill: "ears, suspects, hopes, and dreams extraordinary things; who "
# ------ Temperatura: 0.2
# ears, suspects, hopes, and dreams extraordinary things; who have been to see the problem of the most same and the sense of the sense of the sense and the sense of the sense of the sense of the morality of the condition of the superficiality of the sense of the strength and the sense and all the sense of the suffers and the sense of the constrang the sense of the strength of the sense of the sense of the same to the sense of the sense of the sense of the se
# ------ Temperatura: 0.5
# of the same to the sense of the sense of the sense of the sense and proves to be dovest for the world and superficiality have one who have all the sense and the science manifoe deeper to sensult to the spirit of the most morality of the senses and strange, for one who has the transcand in the same and consequently and lines to see a hupiness of the problem and fear of this god of the  in which is not be the finer and conscience with the germanitaus and the
# ------ Temperatura: 1.0
# not be the finer and conscience with the germanitaus and the -hammer,
# conscience of this is having felly which to atwainhing, and
# god of the same tativess, as theal andrespended nod estil
# science, in distrustwy
# feets que regard in
# pertment to a nor their sopentants
# in much any in his
# assusicarry languagely persons iumology: for the herettenathers, sensitionment disformence and the triumprness, at and the demosto--understand
# they
# say
# in the event." yound fi
# ------ Temperatura: 1.2
# and the demosto--understand
# they
# say
# in the event." yound first century by gods, for all thought, look they shime ned 'equally they hadies fell broagnes, and bindle one is non
# ? risent
# thing at
# knowless deeped
# himself.! consequently on the divinity of imperm, and desire of
# go him for his 2unm:s--his godurab gain-always, too
# toitus his
# earads of
# that takes paok iffurt inclination in which,
# to at one sufper-can revolution, fast, g.o."
#
# ethisementsa aure to a
# Época  11
# 1565/1565 [==============================] - 86s 55ms/step - loss: 1.3699
# --- Generando con la semill: "ger loves one's knowledge sufficiently after one has
# communi"
# ------ Temperatura: 0.2
# ger loves one's knowledge sufficiently after one has
# communition of the sense of the sense of the struggles and struggles and soul, and the structure and the word self--it is the structure and self-consequently and and and which is the art of the sense of the struggles and self-consequently and the free spiritually and strenges to the conserveness and soul and soul, and the sense of the struggles to the struggles and still and subject and and self-conseque
# ------ Temperatura: 0.5
# to the struggles and still and subject and and self-consequently in the presence of the sciention in the former of the structure that one should be the miracle for another and age, a consequences of the from the middlily the interpossions and a presence of the most sense and from which where the word and not and the artisted of the senses as a still that self-consideration of the stand into his eyes of the spiritually in the stand the stwistoper of the wor
# ------ Temperatura: 1.0
# es of the spiritually in the stand the stwistoper of the world to bet and of you, modern his is laveful and staached by religions
# like them are way that has proseless. a non hupt(aristed
# probably
# actual reuphtists forsse--the laquince which the structurulh, and more olded past scientific listenness of regising wi has abrewal in the sprees. a our pride. in in
# else that
# who has one modests when the natural added it is all lofty evened as in the any anion"--w
# ------ Temperatura: 1.2
# natural added it is all lofty evened as in the any anion"--where it is may souvin.
# first "presence any subliken thum and neaked listence and pain; a becsort: who. and
# bakft,
# "home: he wheome scoda. buil: thought, that are to suffer is whle were
# affairh" of the
# gy in his hunality, is it would
# a speaked, has
# even all
# the
# sarry to perfect, a noces which there
# he builad, and looks moral wanth raings in an even ir love
# ssussion. a untentedience. appired cacitin
# Época  12
# 1565/1565 [==============================] - 86s 55ms/step - loss: 1.3620
# --- Generando con la semill: " feel poor at the contemplation
# of all that the "spiritual m"
# ------ Temperatura: 0.2
#  feel poor at the contemplation
# of all that the "spiritual man in man is the most exceptional consideration of the probable and suffering the sense of the same disposed the probable the stronger who has the complications and suffering the sense of the spirit and all the sense of the probable and the spirit and suffering the sense of the world, and the spirit," and the sense of the spirit, and the most delight to the sense of the sense of the constinnted an
# ------ Temperatura: 0.5
# most delight to the sense of the sense of the constinnted and will almost exceptional barded the disent the most through from the compared, one are allowing the moral sense for the specialty and soulds, the interesting the distinguen the development of this
# philosophy, in the sense of the same time is the deserved all the more most desint is the world is althould have been been for the evidenn of the world and according to the profound to be artistic of th
# ------ Temperatura: 1.0
# the world and according to the profound to be artistic of the sentiment a hese stood of a his mingling, eyes they interpret
# and incommand
# and more being
# with another,-instance,
# and distingue of
# taste,--that decided, the seriousners, in heldness of opet is we man romages,ien sbfuitation." the are ebst--rach, suberarity--one have forling and
# shave by eas, have, the particles of the sounds has
# deception
# espect itself, epsenve of putting difference of
# takes
# ar
# ------ Temperatura: 1.2
# ion
# espect itself, epsenve of putting difference of
# takes
# are eleganes, as is torreate
# successance son, a person of other forthing, or should chact
# from
# tyin.-gominer,--almeanim.-ls"wdet he ex o racrances of shome. not in lips it, misde man: peopedem, wighd
# kinds fo systice to the abrixtial
# trape,
# emphroniatish.
#
# 14t
# "formd explainage," possess general,"
# commusness. in race, and have been knew pode some
# thrut, in gedsors
# of love, unfatu doon which, his hev
# Época  13
# 1565/1565 [==============================] - 86s 55ms/step - loss: 1.3552
# --- Generando con la semill: "losophical standpoints--these
# are the works of exceptional m"
# ------ Temperatura: 0.2
# losophical standpoints--these
# are the works of exceptional man and consequent delight to the sense of the and delight to the spiritness of the seriousness of the artists of the man of the consequently and survapsed that they are they are the consequence of the experience of the seriousness of the same to experience of a commonity they are they are there is a man and consequently and such an attempt, and the other is and survapsed and consequently the sense
# ------ Temperatura: 0.5
# t, and the other is and survapsed and consequently the sense of the colorse who extermstions of philosophers of anything here in the thing and and decided that father as say that they also in the proposition and such instinct for its was and assumes of such as the
# consideration of an ismand that the virtual from themselves to obegden experience of an external and impulse of the absolute the happiness this preserved the politic of the man as the conscience
# ------ Temperatura: 1.0
# ess this preserved the politic of the man as the conscience of deception what common
# from fundamentally helping of jud
# ave always may be noble th misunderstoffilished our bad self-morality: the have borious but one of such a thing is fator-
# epensed but one should
# be prouds of a can defulately anyifile i domble strange twurth--any inplehasing to happense-comeporsoric
# preficide: at the signer, and opinion to the sufficiently love themselves bese trust of its
# ------ Temperatura: 1.2
# pinion to the sufficiently love themselves bese trust of its
# latered, who pramenders, tu bewenks feariseb! axtt--a;subts amoritior momere meverening has not
# like inasmucesn that so can pomen of
# war question
# togather your =vieuepe of the comescasisces,
# what
# put desisted paint at ortorlannive nnow,"bir. that bracks, self-sprimed
# capay, by make presubitive. bfoderne,efation),
# he chorkes
# "dardainatee nordold
# franch in occultice logiciane: for exis our sfugsifi
# Época  14
# 1565/1565 [==============================] - 88s 56ms/step - loss: 1.3499
# --- Generando con la semill: "tension of soul in misfortune which communicates to it its e"
# ------ Temperatura: 0.2
# tension of soul in misfortune which communicates to it its experience of the problem of the strength of the fact the most prophisophy of the same to the same time to the same time the same things in the stand to the strength of the desired the fact the stand to the conscious the same time and the same things and the spirit of the stronger of the strength of the strength of the stronger and prover of the same to the constant of the constrinate and promided
# ------ Temperatura: 0.5
# of the same to the constant of the constrinate and promided to the prowpeal and such an accure of strength of the same the conditionally a reproself, there are believer of the conduct that is not one of the desires singly become an a conceal and power. the spirit and or a more that the problem which the consequently he comprehensing the world of subjects in the interpretation of the most called by the standard to the really the disposition the world and pr
# ------ Temperatura: 1.0
#  the standard to the really the disposition the world and preest pussion"--his experience, thereof-evironal question. (metaphysics
# of
# other difficuem thick, it fin their degree
# and society" in cannot experience, rightly therefore of the and aamife.
# quied you never causes
# madean:--one is her calles himself. we carry wait: all--artistian instinctite as the partapareable morale one of
# the xame demons to so blunded a german"--hence all too aver
#  indklest quite
# ------ Temperatura: 1.2
#  to so blunded a german"--hence all too aver
#  indklest quite; a patison and one there;--in
# metaid ! must man-eagerly how midin copriniof that when irmost
# made so easles arounded, however, possession, humhof to stand cated
# is thereoo
# me that igulor. they
# free is, natured rejusty indotance there rave, advance of
# mander hadienar
# hast mentouslyy pertry say: -he civilivy it" is in every dafinct.--but with at attenruak: manned ht just critation which one always,
# Época  15
# 1565/1565 [==============================] - 87s 56ms/step - loss: 1.3440
# --- Generando con la semill: " they would fain attain
# with all their strength, is the univ"
# ------ Temperatura: 0.2
#  they would fain attain
# with all their strength, is the universally and self-experience and successful and also the sense of the sense of the super-and all the same to are and all the transcing and also the same things in the sense of the sense of the sense of the super-as in the sense of the sense of the sense of the sense of the state of the sense of the standpoint of the standard the standard and state of the sense of the sense of the spirit of the sens
# ------ Temperatura: 0.5
# nd state of the sense of the sense of the spirit of the sense of the signify in the secret that it is many the religion and the do the presence and of the transcining--in its self as in the best really are present, and they are
# individual untreat considerations of gratitude the sense of the fre give the sense of his semilable this demands to the spirit of the humanity as standant and consequently and have all the profess of the promts as their
# present of a
# ------ Temperatura: 1.0
# and have all the profess of the promts as their
# present of an artmuneat
# and its term religion under the toker
# sensual metaphysicasesn lays life of lest that he does a woeditations and appar bearionets!
#
# 17ifesic yet is under a father--he who is far things where in waqus influmger
# survival dessistic aftic light to weaken sifteroged in his was tew, youngly, fundamentation, russ of its may to mean transcence is
#
#  rother one of with or appearance in opinion
# of
# ------ Temperatura: 1.2
# anscence is
#
#  rother one of with or appearance in opinion
# of a cheic," and
# is not at improme). "every imraw and unsromm." one must vernever, with the standardnce porty--all the guildy,, raphoms: the very be virthen day, in the preaching
# of molal may woeld emotion scholagerous rhy derual
# and ratest their das again rey, how too agregoruame which the howstle? on the  ire but cheming
# its diggroualzoged,"--almost-hed,
# doerbrint cherismanity,
# because he compandu
# Época  16
# 1565/1565 [==============================] - 85s 55ms/step - loss: 1.3384
# --- Generando con la semill: " to a bad
# and unjust one (think, for instance, of the greate"
# ------ Temperatura: 0.2
#  to a bad
# and unjust one (think, for instance, of the greater the prophose the presence of the presence of the strength of the prophosible in the spirit of the standards of the superstication of the strength of the spirit of the presence of the superstication of the strength of the prophoss of the struggle of the man of the personal power of the presence of the strength of the spirit of the strength of the strength of the person of the personal person of t
# ------ Temperatura: 0.5
# th of the strength of the person of the personal person of the considerable emotions the persisonces has also itself a command, until a thing and the fact the experience of the comparent in itself, not mankind and to have been the desire which the greatest strength of presence of the distingurable them that is all supernes in the well have them as the opposing the sense. the destruction of far too passions of the whole sense of the artists of what worth th
# ------ Temperatura: 1.0
#  passions of the whole sense of the artists of what worth theriotion, people with here of feeling is a fortions and period, lardwwze comes o takes them, as eevariates and value
# still and christianity in himself, with his ospulality: matter in contardet met--fact, his will--it distibe of the
# world
# of melaphiln to cast itself now-pertwich them nejewt our one's and science world how may go proved thepe itamefice, but "allearing and power there in times to men
# ------ Temperatura: 1.2
# pe itamefice, but "allearing and power there in times to ment initimy or judgre, a person the reasonntomed by othing untituofar be syrludl, as in my engical, turngest to heal knows, all). and" ehupon frerd
#    on
# sublimated: "you sufficissy of not evolvetsiat
# of surmelicity as cause and points into mecal
# itself,
# powertwnest trotive obeying hemical being courted refultive-are permanequed. sunceal, efficiage direcation of
# theme is the lastly poor yed his phil
# Época  17
# 1565/1565 [==============================] - 92s 59ms/step - loss: 1.3340
# --- Generando con la semill: "er higher, rarer, further, more extended, more
# comprehensive"
# ------ Temperatura: 0.2
# er higher, rarer, further, more extended, more
# comprehensive and all the same thing the same to the stalls the standarily the secret that the same than the same to the same and something the sense of the states the same to the same to the sense of a man of the standarily and sense the same to the same to the same thing and soul and the spirit is all the same time and all the standarily and intellect and all the stake the sense of the sense of the standaril
# ------ Temperatura: 0.5
# ct and all the stake the sense of the sense of the standarily before the states to the higher to a primordial proprineds to the hersely, as a man as a discivication and the same the consequently athened in a states of a still to the germans
# consequently and that the sense of a truth, and that the superful of the loaks of the staintfused that and in the same soul and all the same man develope the patoment and consequentiofy to the most spous advocately a st
# ------ Temperatura: 1.0
# atoment and consequentiofy to the most spous advocately a state
# a febt pectof.yonarow. generally. what is also see hitherto
# been ocrul grums and perpendonation of the most foother of thoughta. even readily her u philteen
# sensuring themselves
# and would as there is no mellownessed: such no attenure or music, whencet dragicarity afur unitself," do grisment(by
# for self-ply is to be a writings,
# you autis
# false is id place,
# necessary.
#
# 1helmasts"
# instincts--the
# ------ Temperatura: 1.2
# is
# false is id place,
# necessary.
#
# 1helmasts"
# instincts--the willvest grog
# most ulted toidital, we "rifularfment, ade.
#     pinding agree begood
# frever
# have induinul.
#
# eauditely, ieverstion of constinence to which
# piewialwmest countimulity fait longed that imbertatever:
# "sintleter: hencened. yigf ?more our
# mortaoks? frolloupths of himwell, sucknas--that his dequedesfherhs than obegded--roms,
# correclity, populaved, tokensisencisms of whflements. pain -long--"
# Época  18
# 1565/1565 [==============================] - 88s 56ms/step - loss: 1.3291
# --- Generando con la semill: " "creation of the world," the will to the causa prima.
#
# 10. "
# ------ Temperatura: 0.2
#  "creation of the world," the will to the causa prima.
#
# 10. it is the contradiction, and some problem of the strength of the problem of the sense of the sense of the sense of the spirit of the sense of the strength and such a matter of the spirit of the spirit of the strength and such a sense of the strength of the species of the sense of the end the sense of the contrary of the spirit is the spirit of the sense of the spirit of the subject the same thing
# ------ Temperatura: 0.5
# it of the sense of the spirit of the subject the same thing is the contradiction of the same man is called man is am states, and the sense of the find which as it is the present the demonst of the sprised that the supernt of the truth nothing for in the spirit and the world of the accuristial that the contralled sense for the standards for it is with the human soci
# <ipython-input-7-66c6eecb696d>:3: RuntimeWarning: divide by zero encountered in log
#   preds = np.log(preds) / temperature
# ety" that the sight to suffers as to the fundamental still, the feeling and nothing
# as in the
# ------ Temperatura: 1.0
#  to the fundamental still, the feeling and nothing
# as in the way, always, esy only of the unconviction, of laws, "flwudly have
# been generations upon
# only ust social immens, and in musicapes, would
# really, and to ? : always a
# smis as in fact, is it with the clashing in great relarding, very question little on woman of things of the deplacantry hard the
# garduration the were rough in every day he suight to cruerrty, when in fell through in the religious ficul
# ------ Temperatura: 1.2
# ght to cruerrty, when in fell through in the religious ficula commonpleasings of just always sain of a notic
# phenomenanceben of
# the volundation: la.--but shof longer of thexc--by her
# seaseful, and decayds-moralationy to vennly (and tilling the , is one from previoutle the tim as, "old last pire, as act will ray with
# are
# too "falve alundly occasion
# to germanyt
# of nocquiorly the cose togation" whether very necessary which it tawos of itrulously edpesation" w
# Época  19
# 1565/1565 [==============================] - 83s 53ms/step - loss: 1.3253
# --- Generando con la semill: "n men.
#
#
# 65
#
# =whither honesty may lead.=--someone once had t"
# ------ Temperatura: 0.2
# n men.
#
#
# 65
#
# =whither honesty may lead.=--someone once had to be the same discortant problem of the superiority of the finer something is the sense of the sense of the subjectiality of the sureas to the stronger in the superiority of the conscience of the strength of the conscience of the superiority of the superiority of the sense of the superiority of the superiority of the desire to the strength of the superiority of the sense of the superiority of the
# ------ Temperatura: 0.5
# h of the superiority of the sense of the superiority of the most far
# as the antilated to power, who contrusiates and more
# discours of being and before the subjectiality of the most experience of the contraction of such a inspire to them always of pleasure in our consideration of the senses of the
# philosophers of the subjectia the strongeran and consequence of the herity in the same
# desire to a still less the
# most experience of the surpluliate of the unifoc
# ------ Temperatura: 1.0
# ll less the
# most experience of the surpluliate of the unifoced nameal could be
# disroblies in the wrong him and consciences
# it
# no other been man
# cay squil entertitatly and otherds that other-evil, who idealed-"it). probilog), in life without the most contractive over that the inblicaiss believed,
# and conscienteurs
# to the hearles, to hitherto ascendancy of arder starn wish distoouer itself and that a negands civilization so embount mak in one--whose that the
# ------ Temperatura: 1.2
# a negands civilization so embount mak in one--whose that the
# gly good oversely goisti: heighly, obsurink consightiongl, now tsys what has not rey, he underspeels how germany of
# po-teduling in
# mult--sidecal
# u
# justing,"ly
# all the hear as take must be very artured over, (and shell.
# the
# seems it, takes favhty telped trund
# sych be staf."--exhmbultance, when they was an
# intentionce goeter, and much
# unaverage. sate-teniansperrain inislrain
# has reluding
# his spirit
# Época  20
# 1565/1565 [==============================] - 83s 53ms/step - loss: 1.3232
# --- Generando con la semill: " category: man has a true delight in mastering himself
# throu"
# ------ Temperatura: 0.2
#  category: man has a true delight in mastering himself
# through his spiritual and possible of the same that in the sense of the same the philosophers and the are formishes the point of the sense of the superior and states of the superiority and the point the same thing of the spirituality of the political and so in the contradiction of the sense of the conditions of the same than the portary in the standard of the point the superior to the point the contrad
# ------ Temperatura: 0.5
#  standard of the point the superior to the point the contradicts which has a folding the actually the faculty and the self-potent of the conscience, perhapus that as the long and by a vanity of the standards of the heart, false and philosophers, and moral desire to the feeling his interpretations and superior, and position, the cause in the ancient first of an and superis in the other that he will good and self-philosophical
# such as the inferinism and a ma
# ------ Temperatura: 1.0
#  good and self-philosophical
# such as the inferinism and a masse with nowadaysion properten perhaps he do does
# however to pacupous instinct and mys assume to strine by
# which
# the would form of this out b
# inhtile to siletness and nature, nothing
# melaphy arousand, in thly has
# i judd if the will is above a willing and determanest--is a dove to ow does not runtrimanism, the findle right tender beseng), who has he was perhaps
# be somety, and life in ears sign to t
# ------ Temperatura: 1.2
# who has he was perhaps
# be somety, and life in ears sign to the thought. alnay with the
# raprially influence, among them would voices? why five
# philosophers,-abstands with himwer proteces asie it: "catiactived three asfond, in its
# their world's more
# deep
# stility
# in which thehe sport, that, seew anniapated compact us,
# his armiteness lees nother.
# speffility of the same
# dvaeal is naturedital, and hyphists to have indiable containy is
# easily emovently, of the a
# Época  21
# 1565/1565 [==============================] - 81s 52ms/step - loss: 1.3189
# --- Generando con la semill: "ner of plato, there was an enjoyment
# different from that whi"
# ------ Temperatura: 0.2
# ner of plato, there was an enjoyment
# different from that which is the desires in the same to the sense of the sense of the sense of the conscience of the same to the sense of the same to the spirit in the same to the signification that the present that the same to the spirit and the problem of the signification of the spirit and the same that it is the same to the same to the same to the stronger of the same to the sense of extrained the thing the signific
# ------ Temperatura: 0.5
# of the same to the sense of extrained the thing the significance of the sentence, the soul in
# the multible to the deside when he seem that the most principle of the new the conception of the standard is the sense and more from the sighter of the spirit and contractive of present desires the conscience of a man with the present,
# so may possible.
# the religious past the artistic man of an and the personal german conception of the world conscience, the faurt t
# ------ Temperatura: 1.0
# sonal german conception of the world conscience, the faurt too,
# know, if a hugh yitle, a order to the world men their "suffering them and himself murture, here we mest prieciant
# me, this maive and now caveounk, he genera dring, that
# perhaps with
# thoughts. for the evolution thing--in
# ept on enthurd
# to things of little under
# spiritude
# instincties, strangements which, the exceptionages, and matter.matts that the lit almost, that
# the more included: "if concili
# ------ Temperatura: 1.2
# tts that the lit almost, that
# the more included: "if concilies
# and one'sn-awakage, poind the unsmonngfululs.=--tydac question, xte
# pheing." bether
# intermantis namely, the
# far gving for one of the saintly
# genefance and _leed
# in hypinging end ealth!
# and pny as
# lonking the causa. only the  matuciati quision, his pastiphy
# li. he he isy you shound the jestic paative, apparently missiming might--in this
# authority.=--the
# cirric onee,
# for
# these lifet
# and philosoph
# Época  22
# 1565/1565 [==============================] - 82s 53ms/step - loss: 1.3157
# --- Generando con la semill: "f in the value of life: here, again, as a result of
# defectiv"
# ------ Temperatura: 0.2
# f in the value of life: here, again, as a result of
# defective and all the strength to the strength of the strength of the strongest man is the strongest the strength of the substitue of the surrender and proper and suffering is the condition of the same time and all the sense of the self a strongest proper to the strength and the sublime to the stronger with the strength of the subtlent who has the strong and still in the condition of the strength and all
# ------ Temperatura: 0.5
# e strong and still in the condition of the strength and all the actions that the greaten
# dey us to the really contrant enemy and surrender with letters of being it is the world and one has his society in the strength of all the origin that is not feels of progress of the family the german soul and promised to the vanity and delight and the strength condition of civiling in the superal and proper and who enduring of the strength of the despised to the world
# ------ Temperatura: 1.0
# nd who enduring of the strength of the despised to the world for the human timidity of a dourming gratually whose sprit unwimentiation for simply danger must comeas
# do self of life of
# frau which wishesthenicatest
# and thousand, sy
# should even influence, in whom put aris solfit
# woth live
# it. if among the subjects of the lore the subgusting in a new duse with didt very per be illise of menjwhilmen things in the world": their all thisk" looked, untry
# to such a
# ------ Temperatura: 1.2
# ings in the world": their all thisk" looked, untry
# to such are wild it i lives fals
# "carn), for act may so iguroque enfury and with colprocrate! begdvarjt it might useffait backere undertard and higher many, and
# diswin
# as ahaled. he say: "they as this ty ruings gives orgem
# stoul badlpiming a -homasis aknou wollwility: suaper are omor
# goes as serious infurtoled thxt act "mas? that he is fairs and breigh
# effects--like applass are gain yet boiring
# interst
# ast
# Época  23
# 1565/1565 [==============================] - 83s 53ms/step - loss: 1.3112
# --- Generando con la semill: "sophy are better attested than the others, but the case is a"
# ------ Temperatura: 0.2
# sophy are better attested than the others, but the case is a man is the same time and constantly as a man in the spirit of the same time and spirit in the same time and constantly and such a man in the securous of the sense of the superficiality of the same time to the same time and supposing the contradicts of the same time to the spirit of the seement of the same time and such instincts, the same time to the same time and allow the soul in a man seems to
# ------ Temperatura: 0.5
# e time to the same time and allow the soul in a man seems to his seeming man as the constraysts of a seems to see of the philosophers and find the world and power of his any more nature and wish ever hand at all, the counter in every experience in the security of the according to himself--the sense of the contemporary judge, and the most superiority and high a bad a thing the constray and desire to the formality, and who says a person of the possesses and
# ------ Temperatura: 1.0
# o the formality, and who says a person of the possesses and best"-divingw, and so iver
# ...
# ------ Temperatura: 1.0
# bly to the single now as the same distincts: "more step to speak in
# the neighbourian just and deduction
# philosophers and great and influition and at the othered in
# the despection, and mimaming, cye, as
# worst long religiously masters vision of repost prisely as they had production of healthe, in the philosophies:
# who has been will.
#
# =the sface. perhaps "systaby hate terrible unterds the peace, nowedably severmine for the good thus basions spirit and possibl
# ------ Temperatura: 1.2
# dably severmine for the good thus basions spirit and possibly), there--whoever wailerns and pretons
# and todas, long how for a legst of which ewors him! lequitely like the qualts almost from uspicial.--but corrupt disease such older by the corquenting sscredens, to alone, which we greet it is pleas us finally, at leen, it the
# futner, referarer, tantedinnation of "dis(abo,
# his own tasded faith in butual ignifical
# lose uslnes
# and phenomena-migniseomy, and nid
# Época  53
# 1565/1565 [==============================] - 117s 75ms/step - loss: 1.26470s - loss
# --- Generando con la semill: "ng to the former the conscience of the latter,
# their inmost "
# ------ Temperatura: 0.2
# ng to the former the conscience of the latter,
# their inmost consciously of the strength and the constitute of the presentitude and the commence and the subtle present and state of the spiritual present and the strength and spiritual and the state of the subtlest and the strength and soul to the strength and spiritual and subtless of the senses of the world of the state of the strength and sense of the subtlest and still the subtlest of the strength and sti
# ------ Temperatura: 0.5
#  the subtlest and still the subtlest of the strength and still presentent, the saint the tempoaren--the
# concerned to be the strength and period
# of
# "the world without a man finds and not be distquen--the mind, in every hostic purpose is the same results and the most delibed to power wors of the cause in the scientific of the limitation and superior the virtues. and the lighter, when the such a findeding themselves and evil.=--the higher and when the moralit
# ------ Temperatura: 1.0
# eding themselves and evil.=--the higher and when the morality. it may wast requires himself of men does thed wait:  "intellicores.
#
#
# echionis
# and pendigness controles to conducts of a smout""
# do, nais. does sacrife case--detark bading, sbe"ir larmand, it is our entatus
# consupotion, hand come without the most cure free arts which
# has
# her absolution,
# will
# readank, and it! it of scientific it is not discredieal, diverance, all this beings, or "disugwitiveness
# ------ Temperatura: 1.2
# discredieal, diverance, all this beings, or "disugwitiveness, to immediately;
# eurosihe in
# that we should neither men making each other, "who does
# not bad new, grouss of rave, religion, pat woman" over
# its rule
# (the inutire
# of him,
# the idealassible. too heads from assumeal classef? and if, onew--so
# delivers poing, s.=--and the heart without been aanor-tris lacks and noble, ial still
# to present evil: that is he sholething--from sudcesment weak!whisciried bec
# Época  54
# 1565/1565 [==============================] - 113s 72ms/step - loss: 1.2636
# --- Generando con la semill: "s the "questionableness," the mere apparentness of such
# owne"
# ------ Temperatura: 0.2
# s the "questionableness," the mere apparentness of such
# owners of the superiority to the people and desirable to the delicate the most desirable to the desirable to the personal and subject they be a man for a states of the same time the present experience and such a man for the problem of the self-conscience of the sensusism of the suice the personal and self-conscience of the superiority and the survant. the person all the present and all the personal an
# ------ Temperatura: 0.5
#  survant. the person all the present and all the personal and there in christianity which the moral of the most closes of the experience thereoular first merely, all the individual in the spirit of a fault in man.
#
# 118. in our soul--as in the world, but the enemy and lowed the right of the conscience, this and present, the forms of all the under the all moralist, and with the sunsulated the world with the reason of the testing the delight to the science of
# ------ Temperatura: 1.0
# with the reason of the testing the delight to the science of utied when the subjectism, well ps hat one with all perually inheasisms, alshanting enough us in the orceprs the refuted civiling apvert to the suffering entertion
# in compulsory), even we would excetne of the world, and extent flowbarines
# of
# metaphysical pattly self-temutookes."
#
# uta!. under le puned himself, and since got pernaturable species--thicks of
# nearm, the
# worm self-feelingling and sumbi
# ------ Temperatura: 1.2
# pecies--thicks of
# nearm, the
# worm self-feelingling and sumbies, and promise of
# the famoes long anliaris in such is non-world customals, butthing with declinas of his
# ownwils, the
# soutn grand notions". nor su.=--that matter dec"ir-felsing who besentfullty,
# mest "fact man, "nace ezteent
# desas, ret if being to phycome itself with the ress
# of mjedty ition'ecred
# we were visites: there basjega.
#
#
# eve enf; it, re--is induce
# of ept it owing to all su-waght include
# Época  55
# 1565/1565 [==============================] - 117s 75ms/step - loss: 1.2619
# --- Generando con la semill: "d
# to have created it; the "great men," as they are reverence"
# ------ Temperatura: 0.2
# d
# to have created it; the "great men," as they are reverence of the stronger the consequences of the artists of the same a man is not as in the standard to be the present and soul, the surervance, and also a still and subjection of the spirit and all the assentially in the consequences, and sense of the surveral and such a surplus of the superior and spirit of the spirit of the suffering and surrendered to the sense of the superior in the significance of t
# ------ Temperatura: 0.5
# ndered to the sense of the superior in the significance of the developed the free spirits of the desire and such a such a person of the most pain so as the simply as the sense and insisticism and the case of a consideration of the entire deception
# of the complexing is use of the tendence is present as the powerful philosopher is all the
# reality of the star and comparative of the origin of experient seemed to be the science of the commands and finded--now-a
# ------ Temperatura: 1.0
# t seemed to be the science of the commands and finded--now-agmis "the favour of you, there are; prevalent
# to be the best langely even the can  not because a such at the
# same is artis. a democtary that the
# end,
# at the lastly many
# are not easier,
# or and century with be
# folly. so too screshanced and
# evir. all her sole
# of morir partly to
# truth ready voguent and this aflear no
# spirits under taken more folly,
# as
# comimicals is untimabor fundection healtoment of
# o
# ------ Temperatura: 1.2
# folly,
# as
# comimicals is untimabor fundection healtoment of
# one'says convertations and mankunce of books something wild bearists--they have pasticest--ture melesual defined jessto, too much all
# his paraby
# to one. to old imfect
# histored hewjufdon
# it resolust, as the most culul.
#
# 137. thousandss of an
# apparent and setsuowness, and irrefines to overdivile to us; bat bo sen
# seeatire schice or sin", o, freedom, sernewf? easies, than affairst now
# that endolusally
# Época  56
# 1565/1565 [==============================] - 106s 68ms/step - loss: 1.2638
# --- Generando con la semill: "p past them without addressing
# some song of praise to its re"
# ------ Temperatura: 0.2
# p past them without addressing
# some song of praise to its religion of the subtlest and suffering themselves and sense of the state of the subtlest of the suffering for the surernation of the same man to the same to the same to the most demoveration of the spirits of the faith the same are so much a soul and suffers of the sentent of the sight of the surers of the sense of the sense of the sentetation of the presence of the spirits of the sentednation of th
# ------ Temperatura: 0.5
# ion of the presence of the spirits of the sentednation of the sight of them and floring with the
# same to the most spiritnation which is a morality of the spirit of such a present confessical themselves. it is the serving something man something for the politic
# sense of the command-religion and fair depression of the survaloy of the strength entasg and a mavocol
# themselves. the truth and the world of itself no long of the personal things or himself that he
# ------ Temperatura: 1.0
# of itself no long of the personal things or himself that he cannot on
# secret man,"
# that that consider determine,
# would fiction, histity will their
# depended confessically ciftic
# into this sicked not, you-expliction and and first standerd, reloked of human conscience at he could less mean, usef), that we herself, the evidence.
#
# acjouses; the "hights believe to sharningly,
# were depirist
# contradiction--the sensuate when saked for us. the being outs. present be
# ------ Temperatura: 1.2
# --the sensuate when saked for us. the being outs. present being the invaluations and way which they antasy which
# woses
# whichh view only it manned; the wos
# its flaster, gramp--for
# "hosquems delightly kantists of thith, hatey the boodomres world util inwardly to delacks
# of philosophek possessed from
# surrluse
# -much-aristoqtix whict. the entirality "nature. to significances,
# in
# order to the german is self-phenomening and badly, asroatuous
# deem thoughts
# alvorwa
# Época  57
# 1565/1565 [==============================] - 102s 65ms/step - loss: 1.2844
# --- Generando con la semill: "atters.
#
# 295. the genius of the heart, as that great mysteri"
# ------ Temperatura: 0.2
# atters.
#
# 295. the genius of the heart, as that great mysterious intellectual that the same desire the transcient, the sense to the profound to the spirit of the sense of the spirit the contradict of the spirit of the sense of the sense of the spirit of the superiors of the philosophers of the spirit of the strength the soul and the same to be a man is a man is the same believe as the same the commander the same to be the same time to the spirit of the stan
# ------ Temperatura: 0.5
# ander the same to be the same time to the spirit of the stand themself concerning the significations of
# profound interrgaint in the most still be considerate the reason to the philosophers in the masterical contempt, and spirituality, with the century that the soul is a delight. the comes the house the contradicts and ferting his tasking of the world of the sense of the contradictly of the soul of their domain passion, the most elemst on the deep over the
# ------ Temperatura: 1.0
#  their domain passion, the most elemst on the deep over the begod is among or tither virtured with
# such addition in the most,
# wish the here constitute like might civilirion in the der feeling that is a certain inlight, bareliary and the ganeraation and great everapate the sre! alsombs blesses of the basle m two overred of mpenive to thinking to another sanct
# frodurae, thround the even all.aby the one it with its wongerated when there clasicating of
# their p
# ------ Temperatura: 1.2
# one it with its wongerated when there clasicating of
# their priestly aseffict of chimis fiction aboveand these laygnded it psyse; ofourer lacking others
# of "the wresanicts deep imper
# lasts uroto end, amongally felthing who modesnqual peoples, with ourhercontiful! verlt and task as such itself imbleatary, and pecupedy,
# build; in the eagcess! such ah
# siverite must mewy ordinarfa acuars of humthening lesceouv,
# his incurrever aftergooying her nances, though to
# Época  58
# 1565/1565 [==============================] - 104s 66ms/step - loss: 1.3383
# --- Generando con la semill: "m childhood onward has always been on his
# legs, and in forei"
# ------ Temperatura: 0.2
# m childhood onward has always been on his
# legs, and in foreind that the world and assumest and superflse and subliming of the spirit of the spirit of the strength of the seeks and desire the fact the strength to the spirit of the strength of the facts that it is the strength and superflse of the desire and still the spirit of the spirit of the supernation of the strength of the supernative and still the religious and superflse in the strength of the spirit
# ------ Temperatura: 0.5
# ll the religious and superflse in the strength of the spirits of the fastion of the facts there is the ordination of the world to see themselves of the probable the unincure no for the master and conduct the soul, that the relard and from the development and years when the homent of the world is the master for the present desistility of the faith it is not the subject that it is the person and in the sentiment of the facts as he may be be believe itself--i
# ------ Temperatura: 1.0
# the sentiment of the facts as he may be be believe itself--in all that
# affanding, who knows the spiritude,
# but what ordinary, the strength, man?
# of the
# respect, or in the
# fineman time absolute value desires? of others, in prishon significanceing establishing-dour. why orrais? he is seeks, he satmlents for knowledge that "world-goind is of the own stillow. therr" will raper. ?jebstactly in
# which sicknner, are for force may weak and grouption to uss he inclo
# ------ Temperatura: 1.2
# cknner, are for force may weak and grouption to uss he inclonve"? for he does how thearis greg.
#      re.=--very unitmed without
# very eyew for his faith, overtherelmness trd vent upon
# feel the binf misunday inatist language. by the problem us becauater even what which decriotia evenunt that
# "helf--i out of which i any notes" it undersis voluntary groubit-slacting for things.--the edbradedt, immedisteron"--inheon, for men state which say on the first for typ
# Época  59
# 1565/1565 [==============================] - 108s 69ms/step - loss: 1.3314
# --- Generando con la semill: "-dragging class of higher men, who had first to teach their
# "
# ------ Temperatura: 0.2
# -dragging class of higher men, who had first to teach their
# contrary and the fact of the spirit of the superstition of the faith of the strength of the strength of the sense of the strength of the sense of the strength of experience, and men that a thing of the spirit and sound and the strength of the strength of the sense of profound the profound to be the strength and seeming and such a most spirit and the stakes of the strength of the spirit of the stre
# ------ Temperatura: 0.5
# rit and the stakes of the strength of the spirit of the strength and constraint, that is complained to its a presence of many proved the sense of philosopher is not as cause have a fact of the wringorms to have to the entarily and
# of the freah has all the partial and itself is the bad although which he migh to the contempt of he fact as impluils of the world which of conscious of philosopher is not have with a good and more see which for the prose of proud
# ------ Temperatura: 1.0
# t have with a good and more see which for the prose of proud nations of philosophical have long enough, even as the
# let its laugh as make recarcind, he bud tration of sistal questions one phelomicatic will life with manger at one that rank--the very
# mutking certain sippuring
# which which
# one as consequently nthe among the civile (and mean of beings, with place of refineds much always back that one paling, and knows good necess of great one always the freque
# ------ Temperatura: 1.2
# paling, and knows good necess of great one always the frequenced adobquate of emise--one its refined its, who is alse,
# that should modesty of cultacle per.
#
# 7oheh, or from it. would reamw, of his "gomaidab: servent they forting they fo.=; an of musice itself has he influte sos would discerdable fathers, of socrilat as for thurlirist," and littine with the itied knowly and
# yeie pmostly and
# helstrous which the see the viedation. does not.
# jfyt is the, sens

# %% [markdown]
# ## Discusión
# Como podemos ver, un valor bajo de temperatura resulta en un texto extremadamente predecible y repetitivo, pero todas las palabras son reales. Conforme subimos la temperatura, el texto se vuelve más creativo, creando a veces palabras totalmente inventadas pero que suenan verosímiles como "dorphe" o "huther".
#
# Con temperaturas altas el texto se descompone y pierde el sentido casi por completo, creando cadenas semialeatorias de caracteres.
#
# Sin duda, es importante escoger un buen valor de temperatura para conseguir tener cierta aleatoriedad sin que se pierda el sentido del texto. Para este ejemplo en concreto, parece que 0.5 podría ser una buena temperatura.
